# %% [markdown]
# # Fashion SEO Product
#
# In-order to not recieve errors, please execute each cell in order

# %% [markdown]
# ## 1. Initialize Product Model with Text
# Below add text manually or a saved html file path as input by replacing the text and/or html_file below.
# The html document will be main example for this demonstration.

# %%
from model_manager import ProductModel

text = """Shop ethically sourced gold earrings for women at Mejuri.
        Discover 14k gold earrings in a variety of styles made from the highest quality materials.
        Earrings are what I love most.
        """
# this expects either text OR a file. It must this be indicated when intilizing.
# See comment below for file input
data_product_txt = ProductModel(text=text)

html_file = "../project/input/necklace_google.html"

data_product_html = ProductModel(file=html_file)

# %% [markdown]
# ## 2A. Display text entities

# %%
data_product_txt.render_doc()
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Shop ethically sourced gold
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earrings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  for women at Mejuri.<br>        Discover 14k gold
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     earrings
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
#  in a variety of styles made from the highest quality materials.<br>
# ...

# %% [markdown]
# ## 2B. Display html text entities

# %%
data_product_html.render_doc() 
# rendering this might make the display move, may need to refresh browser
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">Please click. here. if you are not redirected within a few seconds.. Accessibility Links. Skip to main content. Accessibility help. Accessibility feedback. Press. /. to jump to the search box.
# <mark class="entity" style="background: #bfeeb7; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     necklace
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PRODUCT</span>
# </mark>
# ...

# %% [markdown]
# ## 3. Initialize widgets
# The widgets recieve input for the next script to run - running this block again will refresh the widgets and remove your input.

# %%
import ipywidgets as widgets
from IPython.display import display

drop_down_entity,drop_down_descriptor,truncate = data_product_html.get_ner_widgets()
display(drop_down_entity)
display(drop_down_descriptor)
display(truncate)
# Out:
# Dropdown(description='Entity', options=('necklace', 'necklaces', 'pendant', 'pendants'), value='necklace')
# Dropdown(description='Descriptor', options=('Adjective(s)', 'Noun(s)', 'Adverb(s)', 'Compound Noun(s)', 'Descr…
# Text(value='10', description='Maximum results', placeholder='10')

# %% [markdown]
# ## 4. Create Table

# %%
# Run this block after you make your choices from the widget above
data_product_html.make_data_table(drop_down_entity.value,drop_down_descriptor.value,truncate.value)
# Out:
# Displaying: 10 results for necklaces
#   Compound Noun(s)  Total Appearances
# 0             gold                 12
# 1             crew                  8
# 2            chain                  6
# 3         everyday                  6
# 4          cartier                  6
# 5           collar                  5
# 6           luxury                  5
# 7             name                  4
# 8             neck                  4
# 9             shop                  4

# %% [markdown]
# ## 5. Pipeline Score Visualization

# %%
from pipeline_visuals import PipeLineVisuals

pipeline_data = PipeLineVisuals()

pipeline_data.make_pipeline_graph()

# %% [markdown]
# ## 6. NER Loss when training

# %%
pipeline_data.make_ner_loss_graph()
